# %% [markdown]
# # Minimization problems with varying input sizes
# ## Scalability analysis
#
# This notebook will hold scalability experiments which test the efficiency of minimization of functions with growing numbers of inputs per function.

# %% [markdown]
# ### Setup

# %%
import sys
CODEBASE = "./codebase"
if CODEBASE not in sys.path:
    sys.path.append(CODEBASE)

from cooperative_evolution_optimizers import GrayBoxOptimizer, BlackBoxOptimizer
from differential_evolution import DifferentialEvolution as DE
from evolution_strategies import EvolutionStrategies as ES
from particle_swarm_optimization import ParticleSwarmOptimization as PSO
from particle_swarm_optimization import *

from fitness_functions import FunctionFactory as FF

import numpy as np
import matplotlib.pyplot as plt
from time import time
from copy import deepcopy as dc

def plot_means_errs(xs, nparray):
    means = np.mean(nparray, axis=-1)
    errs = np.std(nparray, axis=-1)
    plt.errorbar(xs, means, yerr=errs, fmt="--o", capsize=5)

# %% [markdown]
# ---
# # Sphere Fitness Function Tests

# %%
sphere = FF.get_sphere()
input_space_lengths = range(1, 5+1)
lower_bound = -2
upper_bound = 3
goal_fitness = 1e-5
max_generations = 100

run_count = 10 # number of times to run a given optimization setting
function_count = 5 # number of subfunctions that the GBO will optimize

# %% [markdown]
# ## Differential Evolutions Tests

# %%
""" logging performance metrics """
runtimes = np.zeros((len(input_space_lengths), run_count))
evaluation_counts = np.zeros((len(input_space_lengths), run_count))
generation_counts = np.zeros((len(input_space_lengths), run_count))
success_index = 0

""" testing loop """
for setting_index, input_space_length in enumerate(input_space_lengths):
    # initialize information about functions and CC Optimizer
    functions = [sphere]*function_count
    lower_bounds = [lower_bound]*function_count*input_space_length
    upper_bounds = [upper_bound]*function_count*input_space_length
    genetic_algorithms = [DE]*function_count
    genetic_algorithm_arguments = [{}]*function_count
    train_partition = [list(range(i*input_space_length, (i+1)*input_space_length)) for i in range(function_count)]
    input_spaces = train_partition
    
    # run the experiment with the given settings some number of times
    for run_index in range(run_count):
        # create GBO
        gbo = GrayBoxOptimizer(functions = functions,
                       input_spaces = input_spaces,
                       train_partition = train_partition,
                       lower_bounds = lower_bounds,
                       upper_bounds = upper_bounds,
                       genetic_algorithms = genetic_algorithms,
                       genetic_algorithm_arguments = genetic_algorithm_arguments,
                       max_generations = max_generations,
                       goal_fitness = goal_fitness)
        
        # timestamp
        start_time = time()
        
        # run until convergence, timeout, etc.
        while not gbo.has_converged():
            gbo.evolve()
        
        runtimes[setting_index, run_index] = time() - start_time
        evaluation_counts[setting_index, run_index] = gbo.get_evaluations()
        generation_counts[setting_index, run_index] = gbo._generations
        
    # cut off testing if our optimizer didn't perform well enough
    if success_index == setting_index:
        if np.mean(generation_counts[setting_index, :]) <= 0.95*max_generations:
            success_index += 1
            
""" plot results of the experiments """
# generation counts
plt.figure('Generation Counts by Subfunction Input Size')
plt.title('Generation Counts by Subfunction Input Size')
generation_count_means = np.mean(generation_counts[:success_index+1], axis=-1)
generation_count_errors = np.std(generation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = generation_count_means,
             yerr = generation_count_errors,
             fmt = "--o",
             capsize = 5)

# evaluation counts
plt.figure(2)
plt.title('Evaluation Counts by Subfunction Input Size')
evaluation_count_means = np.mean(evaluation_counts[:success_index+1], axis=-1)
evaluation_count_errors = np.std(evaluation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = evaluation_count_means,
             yerr = evaluation_count_errors,
             fmt = "--o",
             capsize = 5)

# runtimes
plt.figure(3)
plt.title('Runtimes by Subfunction Input Size')
runtimes_means = np.mean(runtimes[:success_index+1], axis=-1)
runtimes_errors = np.std(runtimes[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = runtimes_means,
             yerr = runtimes_errors,
             fmt = "--o",
             capsize = 5)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## Particle Swarm Optimization Tests

# %%
""" logging performance metrics """
runtimes = np.zeros((len(input_space_lengths), run_count))
evaluation_counts = np.zeros((len(input_space_lengths), run_count))
generation_counts = np.zeros((len(input_space_lengths), run_count))
success_index = 0

""" testing loop """
for setting_index, input_space_length in enumerate(input_space_lengths):
    # initialize information about functions and CC Optimizer
    functions = [sphere]*function_count
    lower_bounds = [lower_bound]*function_count*input_space_length
    upper_bounds = [upper_bound]*function_count*input_space_length
    genetic_algorithms = [PSO]*function_count
    genetic_algorithm_arguments = [{}]*function_count
    train_partition = [list(range(i*input_space_length, (i+1)*input_space_length)) for i in range(function_count)]
    input_spaces = train_partition
    
    # run the experiment with the given settings some number of times
    for run_index in range(run_count):
        # create GBO
        gbo = GrayBoxOptimizer(functions = functions,
                       input_spaces = input_spaces,
                       train_partition = train_partition,
                       lower_bounds = lower_bounds,
                       upper_bounds = upper_bounds,
                       genetic_algorithms = genetic_algorithms,
                       genetic_algorithm_arguments = genetic_algorithm_arguments,
                       max_generations = max_generations,
                       goal_fitness = goal_fitness)
        
        # timestamp
        start_time = time()
        
        # run until convergence, timeout, etc.
        while not gbo.has_converged():
            gbo.evolve()
        
        runtimes[setting_index, run_index] = time() - start_time
        evaluation_counts[setting_index, run_index] = gbo.get_evaluations()
        generation_counts[setting_index, run_index] = gbo._generations
        
    # cut off testing if our optimizer didn't perform well enough
    if success_index == setting_index:
        if np.mean(generation_counts[setting_index, :]) <= 0.95*max_generations:
            success_index += 1
            
""" plot results of the experiments """
# generation counts
plt.figure(1)
plt.title('Generation Counts by Subfunction Input Size')
generation_count_means = np.mean(generation_counts[:success_index+1], axis=-1)
generation_count_errors = np.std(generation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = generation_count_means,
             yerr = generation_count_errors,
             fmt = "--o",
             capsize = 5)

# evaluation counts
plt.figure(2)
plt.title('Evaluation Counts by Subfunction Input Size')
evaluation_count_means = np.mean(evaluation_counts[:success_index+1], axis=-1)
evaluation_count_errors = np.std(evaluation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = evaluation_count_means,
             yerr = evaluation_count_errors,
             fmt = "--o",
             capsize = 5)

# runtimes
plt.figure(3)
plt.title('Runtimes by Subfunction Input Size')
runtimes_means = np.mean(runtimes[:success_index+1], axis=-1)
runtimes_errors = np.std(runtimes[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = runtimes_means,
             yerr = runtimes_errors,
             fmt = "--o",
             capsize = 5)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## Evolutionary Strategies Tests

# %%
""" logging performance metrics """
runtimes = np.zeros((len(input_space_lengths), run_count))
evaluation_counts = np.zeros((len(input_space_lengths), run_count))
generation_counts = np.zeros((len(input_space_lengths), run_count))
success_index = 0

""" testing loop """
for setting_index, input_space_length in enumerate(input_space_lengths):
    # initialize information about functions and CC Optimizer
    functions = [sphere]*function_count
    lower_bounds = [lower_bound]*function_count*input_space_length
    upper_bounds = [upper_bound]*function_count*input_space_length
    genetic_algorithms = [ES]*function_count
    genetic_algorithm_arguments = [{}]*function_count
    train_partition = [list(range(i*input_space_length, (i+1)*input_space_length)) for i in range(function_count)]
    input_spaces = train_partition
    
    # run the experiment with the given settings some number of times
    for run_index in range(run_count):
        # create GBO
        gbo = GrayBoxOptimizer(functions = functions,
                       input_spaces = input_spaces,
                       train_partition = train_partition,
                       lower_bounds = lower_bounds,
                       upper_bounds = upper_bounds,
                       genetic_algorithms = genetic_algorithms,
                       genetic_algorithm_arguments = genetic_algorithm_arguments,
                       max_generations = max_generations,
                       goal_fitness = goal_fitness)
        
        # timestamp
        start_time = time()
        
        # run until convergence, timeout, etc.
        while not gbo.has_converged():
            gbo.evolve()
        
        runtimes[setting_index, run_index] = time() - start_time
        evaluation_counts[setting_index, run_index] = gbo.get_evaluations()
        generation_counts[setting_index, run_index] = gbo._generations
        
    # cut off testing if our optimizer didn't perform well enough
    if success_index == setting_index:
        if np.mean(generation_counts[setting_index, :]) <= 0.95*max_generations:
            success_index += 1
            
""" plot results of the experiments """
# generation counts
plt.figure(1)
plt.title('Generation Counts by Subfunction Input Size')
generation_count_means = np.mean(generation_counts[:success_index+1], axis=-1)
generation_count_errors = np.std(generation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = generation_count_means,
             yerr = generation_count_errors,
             fmt = "--o",
             capsize = 5)

# evaluation counts
plt.figure(2)
plt.title('Evaluation Counts by Subfunction Input Size')
evaluation_count_means = np.mean(evaluation_counts[:success_index+1], axis=-1)
evaluation_count_errors = np.std(evaluation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = evaluation_count_means,
             yerr = evaluation_count_errors,
             fmt = "--o",
             capsize = 5)

# runtimes
plt.figure(3)
plt.title('Runtimes by Subfunction Input Size')
runtimes_means = np.mean(runtimes[:success_index+1], axis=-1)
runtimes_errors = np.std(runtimes[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = runtimes_means,
             yerr = runtimes_errors,
             fmt = "--o",
             capsize = 5)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# -----
# # Rosenbrock Fitness Function Tests

# %%
rosenbrock = FF.get_rosenbrock()
input_space_lengths = range(1, 5+1)
lower_bound = -2
upper_bound = 3
goal_fitness = 1e-4
max_generations = 250

run_count = 10 # number of times to run a given optimization setting
function_count = 3 # number of subfunctions that the GBO will optimize

# %% [markdown]
# ## Differential Evolutions Tests

# %%
""" logging performance metrics """
runtimes = np.zeros((len(input_space_lengths), run_count))
evaluation_counts = np.zeros((len(input_space_lengths), run_count))
generation_counts = np.zeros((len(input_space_lengths), run_count))
success_index = 0

""" testing loop """
for setting_index, input_space_length in enumerate(input_space_lengths):
    # initialize information about functions and CC Optimizer
    functions = [rosenbrock]*function_count
    lower_bounds = [lower_bound]*function_count*input_space_length
    upper_bounds = [upper_bound]*function_count*input_space_length
    genetic_algorithms = [DE]*function_count
    genetic_algorithm_arguments = [{}]*function_count
    train_partition = [list(range(i*input_space_length, (i+1)*input_space_length)) for i in range(function_count)]
    input_spaces = train_partition
    
    # run the experiment with the given settings some number of times
    for run_index in range(run_count):
        # create GBO
        gbo = GrayBoxOptimizer(functions = functions,
                       input_spaces = input_spaces,
                       train_partition = train_partition,
                       lower_bounds = lower_bounds,
                       upper_bounds = upper_bounds,
                       genetic_algorithms = genetic_algorithms,
                       genetic_algorithm_arguments = genetic_algorithm_arguments,
                       max_generations = max_generations,
                       goal_fitness = goal_fitness)
        
        # timestamp
        start_time = time()
        
        # run until convergence, timeout, etc.
        while not gbo.has_converged():
            gbo.evolve()
        
        runtimes[setting_index, run_index] = time() - start_time
        evaluation_counts[setting_index, run_index] = gbo.get_evaluations()
        generation_counts[setting_index, run_index] = gbo._generations
        
    # cut off testing if our optimizer didn't perform well enough
    if success_index == setting_index:
        if np.mean(generation_counts[setting_index, :]) <= 0.95*max_generations:
            success_index += 1
        
            
""" plot results of the experiments """
# generation counts
plt.figure('Generation Counts by Subfunction Input Size')
plt.title('Generation Counts by Subfunction Input Size')
generation_count_means = np.mean(generation_counts[:success_index+1], axis=-1)
generation_count_errors = np.std(generation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = generation_count_means,
             yerr = generation_count_errors,
             fmt = "--o",
             capsize = 5)

# evaluation counts
plt.figure(2)
plt.title('Evaluation Counts by Subfunction Input Size')
evaluation_count_means = np.mean(evaluation_counts[:success_index+1], axis=-1)
evaluation_count_errors = np.std(evaluation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = evaluation_count_means,
             yerr = evaluation_count_errors,
             fmt = "--o",
             capsize = 5)

# runtimes
plt.figure(3)
plt.title('Runtimes by Subfunction Input Size')
runtimes_means = np.mean(runtimes[:success_index+1], axis=-1)
runtimes_errors = np.std(runtimes[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = runtimes_means,
             yerr = runtimes_errors,
             fmt = "--o",
             capsize = 5)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## Particle Swarm Optimization Tests

# %%
""" logging performance metrics """
runtimes = np.zeros((len(input_space_lengths), run_count))
evaluation_counts = np.zeros((len(input_space_lengths), run_count))
generation_counts = np.zeros((len(input_space_lengths), run_count))
success_index = 0

""" testing loop """
for setting_index, input_space_length in enumerate(input_space_lengths):
    # initialize information about functions and CC Optimizer
    functions = [rosenbrock]*function_count
    lower_bounds = [lower_bound]*function_count*input_space_length
    upper_bounds = [upper_bound]*function_count*input_space_length
    genetic_algorithms = [PSO]*function_count
    genetic_algorithm_arguments = [{}]*function_count
    train_partition = [list(range(i*input_space_length, (i+1)*input_space_length)) for i in range(function_count)]
    input_spaces = train_partition
    
    # run the experiment with the given settings some number of times
    for run_index in range(run_count):
        # create GBO
        gbo = GrayBoxOptimizer(functions = functions,
                       input_spaces = input_spaces,
                       train_partition = train_partition,
                       lower_bounds = lower_bounds,
                       upper_bounds = upper_bounds,
                       genetic_algorithms = genetic_algorithms,
                       genetic_algorithm_arguments = genetic_algorithm_arguments,
                       max_generations = max_generations,
                       goal_fitness = goal_fitness)
        
        # timestamp
        start_time = time()
        
        # run until convergence, timeout, etc.
        while not gbo.has_converged():
            gbo.evolve()
        
        runtimes[setting_index, run_index] = time() - start_time
        evaluation_counts[setting_index, run_index] = gbo.get_evaluations()
        generation_counts[setting_index, run_index] = gbo._generations
        
    # cut off testing if our optimizer didn't perform well enough
    if success_index == setting_index:
        if np.mean(generation_counts[setting_index, :]) <= 0.95*max_generations:
            success_index += 1
            
""" plot results of the experiments """
# generation counts
plt.figure(1)
plt.title('Generation Counts by Subfunction Input Size')
generation_count_means = np.mean(generation_counts[:success_index+1], axis=-1)
generation_count_errors = np.std(generation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = generation_count_means,
             yerr = generation_count_errors,
             fmt = "--o",
             capsize = 5)

# evaluation counts
plt.figure(2)
plt.title('Evaluation Counts by Subfunction Input Size')
evaluation_count_means = np.mean(evaluation_counts[:success_index+1], axis=-1)
evaluation_count_errors = np.std(evaluation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = evaluation_count_means,
             yerr = evaluation_count_errors,
             fmt = "--o",
             capsize = 5)

# runtimes
plt.figure(3)
plt.title('Runtimes by Subfunction Input Size')
runtimes_means = np.mean(runtimes[:success_index+1], axis=-1)
runtimes_errors = np.std(runtimes[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = runtimes_means,
             yerr = runtimes_errors,
             fmt = "--o",
             capsize = 5)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## Evolutionary Strategies Tests

# %%
""" logging performance metrics """
runtimes = np.zeros((len(input_space_lengths), run_count))
evaluation_counts = np.zeros((len(input_space_lengths), run_count))
generation_counts = np.zeros((len(input_space_lengths), run_count))
success_index = 0

""" testing loop """
for setting_index, input_space_length in enumerate(input_space_lengths):
    # initialize information about functions and CC Optimizer
    functions = [rosenbrock]*function_count
    lower_bounds = [lower_bound]*function_count*input_space_length
    upper_bounds = [upper_bound]*function_count*input_space_length
    genetic_algorithms = [ES]*function_count
    genetic_algorithm_arguments = [{}]*function_count
    train_partition = [list(range(i*input_space_length, (i+1)*input_space_length)) for i in range(function_count)]
    input_spaces = train_partition
    
    # run the experiment with the given settings some number of times
    for run_index in range(run_count):
        # create GBO
        gbo = GrayBoxOptimizer(functions = functions,
                       input_spaces = input_spaces,
                       train_partition = train_partition,
                       lower_bounds = lower_bounds,
                       upper_bounds = upper_bounds,
                       genetic_algorithms = genetic_algorithms,
                       genetic_algorithm_arguments = genetic_algorithm_arguments,
                       max_generations = max_generations,
                       goal_fitness = goal_fitness)
        
        # timestamp
        start_time = time()
        
        # run until convergence, timeout, etc.
        while not gbo.has_converged():
            gbo.evolve()
        
        runtimes[setting_index, run_index] = time() - start_time
        evaluation_counts[setting_index, run_index] = gbo.get_evaluations()
        generation_counts[setting_index, run_index] = gbo._generations
        
    # cut off testing if our optimizer didn't perform well enough
    if success_index == setting_index:
        if np.mean(generation_counts[setting_index, :]) <= 0.95*max_generations:
            success_index += 1
            
""" plot results of the experiments """
# generation counts
plt.figure(1)
plt.title('Generation Counts by Subfunction Input Size')
generation_count_means = np.mean(generation_counts[:success_index+1], axis=-1)
generation_count_errors = np.std(generation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = generation_count_means,
             yerr = generation_count_errors,
             fmt = "--o",
             capsize = 5)

# evaluation counts
plt.figure(2)
plt.title('Evaluation Counts by Subfunction Input Size')
evaluation_count_means = np.mean(evaluation_counts[:success_index+1], axis=-1)
evaluation_count_errors = np.std(evaluation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = evaluation_count_means,
             yerr = evaluation_count_errors,
             fmt = "--o",
             capsize = 5)

# runtimes
plt.figure(3)
plt.title('Runtimes by Subfunction Input Size')
runtimes_means = np.mean(runtimes[:success_index+1], axis=-1)
runtimes_errors = np.std(runtimes[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = runtimes_means,
             yerr = runtimes_errors,
             fmt = "--o",
             capsize = 5)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# -----
# # SoREB Fitness Function Tests

# %%
soreb = FF.get_soreb(k=2)
input_space_lengths = range(2, 10+1, 2)
lower_bound = -2
upper_bound = 3
goal_fitness = 1e-3
max_generations = 500

run_count = 10 # number of times to run a given optimization setting
function_count = 3 # number of subfunctions that the GBO will optimize

# %% [markdown]
# ## Differential Evolutions Tests

# %%
""" logging performance metrics """
runtimes = np.zeros((len(input_space_lengths), run_count))
evaluation_counts = np.zeros((len(input_space_lengths), run_count))
generation_counts = np.zeros((len(input_space_lengths), run_count))
success_index = 0

""" testing loop """
for setting_index, input_space_length in enumerate(input_space_lengths):
    # initialize information about functions and CC Optimizer
    functions = [soreb]*function_count
    lower_bounds = [lower_bound]*function_count*input_space_length
    upper_bounds = [upper_bound]*function_count*input_space_length
    genetic_algorithms = [DE]*function_count
    genetic_algorithm_arguments = [{}]*function_count
    train_partition = [list(range(i*input_space_length, (i+1)*input_space_length)) for i in range(function_count)]
    input_spaces = train_partition
    
    # run the experiment with the given settings some number of times
    for run_index in range(run_count):
        # create GBO
        gbo = GrayBoxOptimizer(functions = functions,
                       input_spaces = input_spaces,
                       train_partition = train_partition,
                       lower_bounds = lower_bounds,
                       upper_bounds = upper_bounds,
                       genetic_algorithms = genetic_algorithms,
                       genetic_algorithm_arguments = genetic_algorithm_arguments,
                       max_generations = max_generations,
                       goal_fitness = goal_fitness)
        
        # timestamp
        start_time = time()
        
        # run until convergence, timeout, etc.
        while not gbo.has_converged():
            gbo.evolve()
        
        runtimes[setting_index, run_index] = time() - start_time
        evaluation_counts[setting_index, run_index] = gbo.get_evaluations()
        generation_counts[setting_index, run_index] = gbo._generations
        
    # cut off testing if our optimizer didn't perform well enough
    if success_index == setting_index:
        if np.mean(generation_counts[setting_index, :]) <= 0.95*max_generations:
            success_index += 1
        
            
""" plot results of the experiments """
# generation counts
plt.figure('Generation Counts by Subfunction Input Size')
plt.title('Generation Counts by Subfunction Input Size')
generation_count_means = np.mean(generation_counts[:success_index+1], axis=-1)
generation_count_errors = np.std(generation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = generation_count_means,
             yerr = generation_count_errors,
             fmt = "--o",
             capsize = 5)

# evaluation counts
plt.figure(2)
plt.title('Evaluation Counts by Subfunction Input Size')
evaluation_count_means = np.mean(evaluation_counts[:success_index+1], axis=-1)
evaluation_count_errors = np.std(evaluation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = evaluation_count_means,
             yerr = evaluation_count_errors,
             fmt = "--o",
             capsize = 5)

# runtimes
plt.figure(3)
plt.title('Runtimes by Subfunction Input Size')
runtimes_means = np.mean(runtimes[:success_index+1], axis=-1)
runtimes_errors = np.std(runtimes[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = runtimes_means,
             yerr = runtimes_errors,
             fmt = "--o",
             capsize = 5)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## Particle Swarm Optimization Tests

# %%
""" logging performance metrics """
runtimes = np.zeros((len(input_space_lengths), run_count))
evaluation_counts = np.zeros((len(input_space_lengths), run_count))
generation_counts = np.zeros((len(input_space_lengths), run_count))
success_index = 0

""" testing loop """
for setting_index, input_space_length in enumerate(input_space_lengths):
    # initialize information about functions and CC Optimizer
    functions = [soreb]*function_count
    lower_bounds = [lower_bound]*function_count*input_space_length
    upper_bounds = [upper_bound]*function_count*input_space_length
    genetic_algorithms = [PSO]*function_count
    genetic_algorithm_arguments = [{}]*function_count
    train_partition = [list(range(i*input_space_length, (i+1)*input_space_length)) for i in range(function_count)]
    input_spaces = train_partition
    
    # run the experiment with the given settings some number of times
    for run_index in range(run_count):
        # create GBO
        gbo = GrayBoxOptimizer(functions = functions,
                       input_spaces = input_spaces,
                       train_partition = train_partition,
                       lower_bounds = lower_bounds,
                       upper_bounds = upper_bounds,
                       genetic_algorithms = genetic_algorithms,
                       genetic_algorithm_arguments = genetic_algorithm_arguments,
                       max_generations = max_generations,
                       goal_fitness = goal_fitness)
        
        # timestamp
        start_time = time()
        
        # run until convergence, timeout, etc.
        while not gbo.has_converged():
            gbo.evolve()
        
        runtimes[setting_index, run_index] = time() - start_time
        evaluation_counts[setting_index, run_index] = gbo.get_evaluations()
        generation_counts[setting_index, run_index] = gbo._generations
        
    # cut off testing if our optimizer didn't perform well enough
    if success_index == setting_index:
        if np.mean(generation_counts[setting_index, :]) <= 0.95*max_generations:
            success_index += 1
            
""" plot results of the experiments """
# generation counts
plt.figure(1)
plt.title('Generation Counts by Subfunction Input Size')
generation_count_means = np.mean(generation_counts[:success_index+1], axis=-1)
generation_count_errors = np.std(generation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = generation_count_means,
             yerr = generation_count_errors,
             fmt = "--o",
             capsize = 5)

# evaluation counts
plt.figure(2)
plt.title('Evaluation Counts by Subfunction Input Size')
evaluation_count_means = np.mean(evaluation_counts[:success_index+1], axis=-1)
evaluation_count_errors = np.std(evaluation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = evaluation_count_means,
             yerr = evaluation_count_errors,
             fmt = "--o",
             capsize = 5)

# runtimes
plt.figure(3)
plt.title('Runtimes by Subfunction Input Size')
runtimes_means = np.mean(runtimes[:success_index+1], axis=-1)
runtimes_errors = np.std(runtimes[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = runtimes_means,
             yerr = runtimes_errors,
             fmt = "--o",
             capsize = 5)
# Out:
# <ErrorbarContainer object of 3 artists>

# %% [markdown]
# ## Evolutionary Strategies Tests

# %%
""" logging performance metrics """
runtimes = np.zeros((len(input_space_lengths), run_count))
evaluation_counts = np.zeros((len(input_space_lengths), run_count))
generation_counts = np.zeros((len(input_space_lengths), run_count))
success_index = 0

""" testing loop """
for setting_index, input_space_length in enumerate(input_space_lengths):
    # initialize information about functions and CC Optimizer
    functions = [soreb]*function_count
    lower_bounds = [lower_bound]*function_count*input_space_length
    upper_bounds = [upper_bound]*function_count*input_space_length
    genetic_algorithms = [ES]*function_count
    genetic_algorithm_arguments = [{}]*function_count
    train_partition = [list(range(i*input_space_length, (i+1)*input_space_length)) for i in range(function_count)]
    input_spaces = train_partition
    
    # run the experiment with the given settings some number of times
    for run_index in range(run_count):
        # create GBO
        gbo = GrayBoxOptimizer(functions = functions,
                       input_spaces = input_spaces,
                       train_partition = train_partition,
                       lower_bounds = lower_bounds,
                       upper_bounds = upper_bounds,
                       genetic_algorithms = genetic_algorithms,
                       genetic_algorithm_arguments = genetic_algorithm_arguments,
                       max_generations = max_generations,
                       goal_fitness = goal_fitness)
        
        # timestamp
        start_time = time()
        
        # run until convergence, timeout, etc.
        while not gbo.has_converged():
            gbo.evolve()
        
        runtimes[setting_index, run_index] = time() - start_time
        evaluation_counts[setting_index, run_index] = gbo.get_evaluations()
        generation_counts[setting_index, run_index] = gbo._generations
        
    # cut off testing if our optimizer didn't perform well enough
    if success_index == setting_index:
        if np.mean(generation_counts[setting_index, :]) <= 0.95*max_generations:
            success_index += 1
            
""" plot results of the experiments """
# generation counts
plt.figure(1)
plt.title('Generation Counts by Subfunction Input Size')
generation_count_means = np.mean(generation_counts[:success_index+1], axis=-1)
generation_count_errors = np.std(generation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = generation_count_means,
             yerr = generation_count_errors,
             fmt = "--o",
             capsize = 5)

# evaluation counts
plt.figure(2)
plt.title('Evaluation Counts by Subfunction Input Size')
evaluation_count_means = np.mean(evaluation_counts[:success_index+1], axis=-1)
evaluation_count_errors = np.std(evaluation_counts[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = evaluation_count_means,
             yerr = evaluation_count_errors,
             fmt = "--o",
             capsize = 5)

# runtimes
plt.figure(3)
plt.title('Runtimes by Subfunction Input Size')
runtimes_means = np.mean(runtimes[:success_index+1], axis=-1)
runtimes_errors = np.std(runtimes[:success_index+1], axis=-1)

plt.errorbar(x = input_space_lengths[:success_index+1],
             y = runtimes_means,
             yerr = runtimes_errors,
             fmt = "--o",
             capsize = 5)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-21-37c44c025b81> in <module>
#      34         # run until convergence, timeout, etc.
#      35         while not gbo.has_converged():
# ---> 36             gbo.evolve()
#      37
#      38         runtimes[setting_index, run_index] = time() - start_time
#
# ~/Documents/school/undergrad/2018-2019/springSemester/CS4205/assignments/practical2/codebase/cooperative_evolution_optimizers.py in evolve(self)
#     193         # now project all subgenotypes onto the current optimal genotype where applicable
#     194         for subpopulation in self._subpopulations:
# --> 195             subpopulation._optimizer.evolve(genotype, subpopulation._index_mapping)
#     196
#     197     def has_converged(self):
#
# ...
